# %%
import pandas as pd
import numpy as np
from scipy.stats import poisson 
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

# %%
def league_matches(x):
    dfList = []
    for i in range(5, 21):
        df=pd.read_csv("http://www.football-data.co.uk/mmz4281/{0:02d}{1:02d}".format(i,i+1)+f"/{x}.csv",error_bad_lines=False,encoding='latin1')
        
        df = df[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HS', 'AS','B365H', 'B365D', 'B365A']]
        dfList.append(df)
        Data = dfList[0].append(dfList[1:])
    return Data

# %%
# %%time
Bundesliga=league_matches('D1')
EPL=league_matches('E0')
LaLiga=league_matches('SP1')
SerieA=league_matches('I1')
# Out:
# CPU times: user 1.51 s, sys: 341 ms, total: 1.85 s
# Wall time: 1min 14s

# %%
Bundesliga
# Out:
#           Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HS  AS  B365H  \
# 0     05/08/05  Bayern Munich     M'gladbach     3     0   H  19  10   1.30
# 1     06/08/05       Duisburg      Stuttgart     1     1   D  11  11   2.75
# 2     06/08/05        FC Koln          Mainz     1     0   H  14  19   2.10
# 3     06/08/05        Hamburg       Nurnberg     3     0   H  12  17   1.57
# 4     06/08/05       Hannover         Hertha     2     2   D  12  15   2.40
# ..         ...            ...            ...   ...   ...  ..  ..  ..    ...
# 13  26/09/2020          Mainz      Stuttgart     1     4   A  11  15   2.37
# 14  26/09/2020     M'gladbach   Union Berlin     1     1   D  14  15   1.44
# 15  26/09/2020     Schalke 04  Werder Bremen     1     3   A  17  17   2.50
# 16  27/09/2020     Hoffenheim  Bayern Munich     4     1   H  17  14  11.00
# 17  27/09/2020       Freiburg      Wolfsburg     1     1   D  21   8   3.20
#
#     B365D  B365A
# 0    5.00   9.50
# 1    3.25   2.25
# 2    3.25   3.00
# 3    3.40   5.50
# 4    3.20   2.60
# ..    ...    ...
# 13   3.50   2.90
# 14   4.50   7.50
# 15   3.40   2.80
# 16   7.50   1.20
# 17   3.30   2.30
#
# [4608 rows x 11 columns]

# %%
EPL
# Out:
#           Date       HomeTeam     AwayTeam  FTHG  FTAG FTR    HS    AS  B365H  \
# 0     13/08/05    Aston Villa       Bolton   2.0   2.0   D   3.0  13.0   2.30
# 1     13/08/05        Everton   Man United   0.0   2.0   A  10.0  12.0   5.00
# 2     13/08/05         Fulham   Birmingham   0.0   0.0   D  15.0   7.0   2.37
# 3     13/08/05       Man City    West Brom   0.0   0.0   D  15.0  13.0   1.72
# 4     13/08/05  Middlesbrough    Liverpool   0.0   0.0   D   4.0  16.0   2.87
# ..         ...            ...          ...   ...   ...  ..   ...   ...    ...
# 23  27/09/2020      Tottenham    Newcastle   1.0   1.0   D  23.0   6.0   1.45
# 24  27/09/2020       Man City    Leicester   2.0   5.0   A  16.0   7.0   1.28
# 25  27/09/2020       West Ham       Wolves   4.0   0.0   H  15.0  11.0   3.60
# 26  28/09/2020         Fulham  Aston Villa   0.0   3.0   A  16.0  12.0   2.90
# 27  28/09/2020      Liverpool      Arsenal   3.0   1.0   H  21.0   4.0   1.45
#
#     B365D  B365A
# 0    3.25   3.00
# 1    3.40   1.72
# 2    3.25   2.87
# 3    3.40   5.00
# 4    3.20   2.40
# ..    ...    ...
# 23   4.50   7.00
# 24   6.00   9.50
# 25   3.50   2.05
# 26   3.25   2.50
# 27   4.75   6.50
#
# [5729 rows x 11 columns]

# %%
LaLiga
# Out:
#           Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HS  AS  B365H  B365D  \
# 0     27/08/05      Alaves    Barcelona     0     0   D   5  17   7.00   3.75
# 1     27/08/05  Ath Bilbao     Sociedad     3     0   H  10   9   2.00   3.25
# 2     27/08/05    Valencia        Betis     1     0   H   9  14   2.00   3.25
# 3     28/08/05  Ath Madrid     Zaragoza     0     0   D  16   9   1.72   3.40
# 4     28/08/05       Cadiz  Real Madrid     1     2   A  15  17   7.50   4.00
# ..         ...         ...          ...   ...   ...  ..  ..  ..    ...    ...
# 19  27/09/2020       Eibar   Ath Bilbao     1     2   A   7   9   3.00   3.00
# 20  27/09/2020  Ath Madrid      Granada     6     1   H  17  11   1.50   4.00
# 21  27/09/2020       Cadiz      Sevilla     1     3   A  12  14   5.00   3.60
# 22  27/09/2020  Valladolid        Celta     1     1   D  10   5   2.80   3.00
# 23  27/09/2020   Barcelona   Villarreal     4     0   H  17   5   1.53   4.33
#
#     B365A
# 0    1.50
# 1    3.25
# 2    3.25
# 3    4.00
# 4    1.44
# ..    ...
# 19   2.55
# 20   7.50
# 21   1.70
# 22   2.70
# 23   6.00
#
# [5724 rows x 11 columns]

# %%
EPL.isnull().sum()
# Out:
# Date        1
# HomeTeam    1
# AwayTeam    1
# FTHG        1
# FTAG        1
# FTR         1
# HS          1
# AS          1
# B365H       1
# B365D       1
# B365A       1
# dtype: int64

# %%
EPL_isna = EPL[EPL.isna().any(axis=1)]

# %%
EPL_isna
# Out:
#     Date HomeTeam AwayTeam  FTHG  FTAG  FTR  HS  AS  B365H  B365D  B365A
# 380  NaN      NaN      NaN   NaN   NaN  NaN NaN NaN    NaN    NaN    NaN

# %%
EPL=EPL.dropna()

# %%
SerieA_isna = SerieA[SerieA.isna().any(axis=1)]

# %%
SerieA_isna
# Out:
#          Date    HomeTeam  AwayTeam  FTHG  FTAG  FTR    HS    AS  B365H  \
# 85   26/10/05       Lazio    Chievo   2.0   2.0    D   NaN   NaN   2.00
# 132  04/12/05  Fiorentina  Juventus   1.0   2.0    A   NaN   NaN   2.87
# 133  04/12/05       Lazio     Siena   3.0   2.0    H   NaN   NaN   1.80
# 134  04/12/05       Lecce      Roma   2.0   2.0    D   NaN   NaN   3.25
# 135  04/12/05     Palermo  Cagliari   2.0   2.0    D   NaN   NaN   1.61
# 136  04/12/05     Reggina     Parma   2.0   1.0    H   NaN   NaN   1.90
# 137  04/12/05   Sampdoria    Empoli   2.0   0.0    H   NaN   NaN   1.66
# 138  04/12/05     Treviso   Messina   0.0   0.0    D   NaN   NaN   2.40
# 139  04/12/05     Udinese   Livorno   0.0   2.0    A   NaN   NaN   1.80
# 140  10/12/05  Fiorentina   Treviso   1.0   0.0    H   NaN   NaN   1.28
# 141  10/12/05       Siena    Empoli   1.0   0.0    H   NaN   NaN   2.10
# 146  11/12/05     Messina    Chievo   2.0   0.0    H   NaN   NaN   2.60
# 150  17/12/05       Lazio  Juventus   1.0   1.0    D   NaN   NaN   6.00
# 151  17/12/05     Treviso     Lecce   2.0   1.0    H   NaN   NaN   2.50
# 327  09/04/06       Parma   Reggina   4.0   0.0    H  12.0  14.0    NaN
# 333  15/04/06      Empoli     Siena   2.0   1.0    H  10.0  14.0    NaN
# 360  09/05/10     Bologna   Catania   1.0   1.0    D   6.0   6.0    NaN
# 325  17/04/11      Chievo   Bologna   2.0   0.0    H  19.0   8.0    NaN
# 327  17/04/11       Genoa   Brescia   3.0   0.0    H  13.0  18.0    NaN
# 34   23/09/12    Cagliari      Roma   0.0   3.0    A   NaN   NaN   3.10
# 380       NaN         NaN       NaN   NaN   NaN  NaN   NaN   NaN    NaN
# 381       NaN         NaN       NaN   NaN   NaN  NaN   NaN   NaN    NaN
# 382       NaN         NaN       NaN   NaN   NaN  NaN   NaN   NaN    NaN
# 380       NaN         NaN       NaN   NaN   NaN  NaN   NaN   NaN    NaN
# 380       NaN         NaN       NaN   NaN   NaN  NaN   NaN   NaN    NaN
#
#      B365D  B365A
# 85    3.00   4.00
# 132   3.00   2.30
# 133   3.00   4.33
# 134   3.00   2.10
# 135   3.25   5.50
# 136   3.00   3.80
# 137   3.20   5.00
# 138   2.75   3.00
# 139   3.00   4.33
# 140   5.00  10.00
# 141   3.00   3.75
# 146   2.87   2.90
# 150   3.20   1.66
# 151   3.00   2.90
# 327    NaN    NaN
# 333    NaN    NaN
# 360    NaN    NaN
# 325    NaN    NaN
# 327    NaN    NaN
# 34    3.50   2.20
# 380    NaN    NaN
# 381    NaN    NaN
# 382    NaN    NaN
# 380    NaN    NaN
# 380    NaN    NaN

# %%
SerieA.dropna(axis = 0, how = 'all', inplace = True)
SerieA
# Out:
#           Date    HomeTeam   AwayTeam  FTHG  FTAG FTR    HS    AS  B365H  \
# 0     27/08/05  Fiorentina  Sampdoria   2.0   1.0   H  15.0   9.0   2.20
# 1     27/08/05     Livorno      Lecce   2.0   1.0   H  17.0   6.0   1.90
# 2     28/08/05      Ascoli      Milan   1.0   1.0   D   8.0  16.0   7.50
# 3     28/08/05       Inter    Treviso   3.0   0.0   H  16.0   7.0   1.16
# 4     28/08/05    Juventus     Chievo   1.0   0.0   H  16.0   2.0   1.25
# ..         ...         ...        ...   ...   ...  ..   ...   ...    ...
# 12  27/09/2020      Napoli      Genoa   6.0   0.0   H  18.0   3.0   1.30
# 13  27/09/2020      Verona    Udinese   1.0   0.0   H   8.0  14.0   2.70
# 14  27/09/2020     Crotone      Milan   0.0   2.0   A   5.0  11.0   6.00
# 15  27/09/2020        Roma   Juventus   2.0   2.0   D   7.0   6.0   3.60
# 16  28/09/2020     Bologna      Parma   4.0   1.0   H  11.0   8.0   1.95
#
#     B365D  B365A
# 0    2.87   3.25
# 1    2.90   4.00
# 2    3.75   1.40
# 3    5.50  13.00
# 4    5.00  13.00
# ..    ...    ...
# 12   5.50  10.00
# 13   3.00   2.80
# 14   4.50   1.50
# 15   3.60   2.00
# 16   3.60   3.60
#
# [5717 rows x 11 columns]

# %%
#There´s different date formats, so let´s homogenize them, to convert them to datetime type
def date_correction(y):
    x=y.split('/')
    if len(x[-1])==2:
        aux='20'+x[-1]
        x.pop(-1)
        x.append(aux)
    else:
        pass
    return ('/'.join(x))

# %%
Bundesliga['Date']=Bundesliga['Date'].apply(date_correction)
EPL['Date']=EPL['Date'].apply(date_correction)
LaLiga['Date']=LaLiga['Date'].apply(date_correction)
#SerieA['Date']=SerieA['Date'].apply(date_correction)

# %%
##adding season column to the df
# %pprint
lst=[]
for i in range(5, 21):
    a="{0:02d}{1:02d}".format(i,i+1)
    lst.append(a)
    
lst
lst=sorted(lst*380) #This list works for leagues that has 20 teams, and 380 games per season
lst=['20'+x for x in lst]

lst_bundes=[]
for i in range(5, 21):
    a="{0:02d}{1:02d}".format(i,i+1)
    lst_bundes.append(a)
    
lst_bundes=sorted(lst_bundes*306) #This list works Bundesliga that has 18 teams, and 306 games per season
lst_bundes=['20'+x for x in lst_bundes]
# Out:
# Pretty printing has been turned ON

# %%
def add_season(league):
    a=len(lst)-len(league['Date'])
    ##to fit the dataframe knowing the difference of the length of the list and the rows
    lista=lst[:-a]
    league['season']=lista
    
    return league

# %%
add_season(LaLiga)
LaLiga
# Out:
#           Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HS  AS  B365H  B365D  \
# 0   27/08/2005      Alaves    Barcelona     0     0   D   5  17   7.00   3.75
# 1   27/08/2005  Ath Bilbao     Sociedad     3     0   H  10   9   2.00   3.25
# 2   27/08/2005    Valencia        Betis     1     0   H   9  14   2.00   3.25
# 3   28/08/2005  Ath Madrid     Zaragoza     0     0   D  16   9   1.72   3.40
# 4   28/08/2005       Cadiz  Real Madrid     1     2   A  15  17   7.50   4.00
# ..         ...         ...          ...   ...   ...  ..  ..  ..    ...    ...
# 19  27/09/2020       Eibar   Ath Bilbao     1     2   A   7   9   3.00   3.00
# 20  27/09/2020  Ath Madrid      Granada     6     1   H  17  11   1.50   4.00
# 21  27/09/2020       Cadiz      Sevilla     1     3   A  12  14   5.00   3.60
# 22  27/09/2020  Valladolid        Celta     1     1   D  10   5   2.80   3.00
# 23  27/09/2020   Barcelona   Villarreal     4     0   H  17   5   1.53   4.33
#
#     B365A  season
# 0    1.50  200506
# 1    3.25  200506
# 2    3.25  200506
# 3    4.00  200506
# 4    1.44  200506
# ..    ...     ...
# 19   2.55  202021
# 20   7.50  202021
# 21   1.70  202021
# 22   2.70  202021
# 23   6.00  202021
#
# [5724 rows x 12 columns]

# %%
add_season(EPL)
EPL
# Out:
#           Date       HomeTeam     AwayTeam  FTHG  FTAG FTR    HS    AS  B365H  \
# 0   13/08/2005    Aston Villa       Bolton   2.0   2.0   D   3.0  13.0   2.30
# 1   13/08/2005        Everton   Man United   0.0   2.0   A  10.0  12.0   5.00
# 2   13/08/2005         Fulham   Birmingham   0.0   0.0   D  15.0   7.0   2.37
# 3   13/08/2005       Man City    West Brom   0.0   0.0   D  15.0  13.0   1.72
# 4   13/08/2005  Middlesbrough    Liverpool   0.0   0.0   D   4.0  16.0   2.87
# ..         ...            ...          ...   ...   ...  ..   ...   ...    ...
# 23  27/09/2020      Tottenham    Newcastle   1.0   1.0   D  23.0   6.0   1.45
# 24  27/09/2020       Man City    Leicester   2.0   5.0   A  16.0   7.0   1.28
# 25  27/09/2020       West Ham       Wolves   4.0   0.0   H  15.0  11.0   3.60
# 26  28/09/2020         Fulham  Aston Villa   0.0   3.0   A  16.0  12.0   2.90
# 27  28/09/2020      Liverpool      Arsenal   3.0   1.0   H  21.0   4.0   1.45
#
#     B365D  B365A  season
# 0    3.25   3.00  200506
# 1    3.40   1.72  200506
# 2    3.25   2.87  200506
# 3    3.40   5.00  200506
# 4    3.20   2.40  200506
# ..    ...    ...     ...
# 23   4.50   7.00  202021
# 24   6.00   9.50  202021
# 25   3.50   2.05  202021
# 26   3.25   2.50  202021
# 27   4.75   6.50  202021
#
# [5728 rows x 12 columns]

# %%
add_season(SerieA)
SerieA
# Out:
#           Date    HomeTeam   AwayTeam  FTHG  FTAG FTR    HS    AS  B365H  \
# 0     27/08/05  Fiorentina  Sampdoria   2.0   1.0   H  15.0   9.0   2.20
# 1     27/08/05     Livorno      Lecce   2.0   1.0   H  17.0   6.0   1.90
# 2     28/08/05      Ascoli      Milan   1.0   1.0   D   8.0  16.0   7.50
# 3     28/08/05       Inter    Treviso   3.0   0.0   H  16.0   7.0   1.16
# 4     28/08/05    Juventus     Chievo   1.0   0.0   H  16.0   2.0   1.25
# ..         ...         ...        ...   ...   ...  ..   ...   ...    ...
# 12  27/09/2020      Napoli      Genoa   6.0   0.0   H  18.0   3.0   1.30
# 13  27/09/2020      Verona    Udinese   1.0   0.0   H   8.0  14.0   2.70
# 14  27/09/2020     Crotone      Milan   0.0   2.0   A   5.0  11.0   6.00
# 15  27/09/2020        Roma   Juventus   2.0   2.0   D   7.0   6.0   3.60
# 16  28/09/2020     Bologna      Parma   4.0   1.0   H  11.0   8.0   1.95
#
#     B365D  B365A  season
# 0    2.87   3.25  200506
# 1    2.90   4.00  200506
# 2    3.75   1.40  200506
# 3    5.50  13.00  200506
# 4    5.00  13.00  200506
# ..    ...    ...     ...
# 12   5.50  10.00  202021
# 13   3.00   2.80  202021
# 14   4.50   1.50  202021
# 15   3.60   2.00  202021
# 16   3.60   3.60  202021
#
# [5717 rows x 12 columns]

# %%
b=len(lst_bundes)-len(Bundesliga['Date'])
lista_b=lst_bundes[:-b]
Bundesliga['season']=lista_b

# %%
Bundesliga
# Out:
#           Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HS  AS  B365H  \
# 0   05/08/2005  Bayern Munich     M'gladbach     3     0   H  19  10   1.30
# 1   06/08/2005       Duisburg      Stuttgart     1     1   D  11  11   2.75
# 2   06/08/2005        FC Koln          Mainz     1     0   H  14  19   2.10
# 3   06/08/2005        Hamburg       Nurnberg     3     0   H  12  17   1.57
# 4   06/08/2005       Hannover         Hertha     2     2   D  12  15   2.40
# ..         ...            ...            ...   ...   ...  ..  ..  ..    ...
# 13  26/09/2020          Mainz      Stuttgart     1     4   A  11  15   2.37
# 14  26/09/2020     M'gladbach   Union Berlin     1     1   D  14  15   1.44
# 15  26/09/2020     Schalke 04  Werder Bremen     1     3   A  17  17   2.50
# 16  27/09/2020     Hoffenheim  Bayern Munich     4     1   H  17  14  11.00
# 17  27/09/2020       Freiburg      Wolfsburg     1     1   D  21   8   3.20
#
#     B365D  B365A  season
# 0    5.00   9.50  200506
# 1    3.25   2.25  200506
# 2    3.25   3.00  200506
# 3    3.40   5.50  200506
# 4    3.20   2.60  200506
# ..    ...    ...     ...
# 13   3.50   2.90  202021
# 14   4.50   7.50  202021
# 15   3.40   2.80  202021
# 16   7.50   1.20  202021
# 17   3.30   2.30  202021
#
# [4608 rows x 12 columns]

# %% [markdown]
# # Shots and Goals Analysis

# %% [markdown]
# Let´s find out how many shots go up in the final score, in other words the shot efficency.

# %%
def shots(league):
    league_shots=league.copy()
    league_shots.drop(['B365H','B365D','B365A'],axis=1,inplace=True)
    league_shots['HomeConversion'] = league_shots.apply(lambda row: round((row.FTHG/row.HS)*100,2) if row.HS !=0 else 0, axis=1)
    league_shots['AwayConversion'] = league_shots.apply(lambda row: round((row.FTAG/row.AS)*100,2) if row.AS !=0 else 0, axis=1)
    home_shots=league_shots.groupby(['HomeTeam'])['HS'].mean()
    home_shots.sort_values(axis=0, ascending=False, inplace=True)
    away_shots=league_shots.groupby(['AwayTeam'])['AS'].mean()
    away_shots.sort_values(axis=0, ascending=False, inplace=True)
    home_conversion= league_shots.groupby(['HomeTeam'])['HomeConversion'].mean()
    home_conversion.sort_values(axis=0, ascending=False, inplace=True)
    away_conversion= league_shots.groupby(['AwayTeam'])['AwayConversion'].mean()
    away_conversion.sort_values(axis=0, ascending=False, inplace=True)
    
    fig,axes = plt.subplots(figsize = (15,15),nrows = 2, ncols = 2)
    plt.sca(axes[0][0])
    home_shots[:10].plot(kind = 'bar',color='red',alpha = 0.5)
    plt.ylabel('Average Shots')
    plt.title('Home Shots (2005/06 to 2020/21)')

    plt.sca(axes[0][1])
    away_shots[:10].plot(kind = 'bar',alpha = 0.5,color='blue')
    plt.ylabel('Average Shots')
    plt.title('Away Shots (2005/06 to 2020/21)')
    
    plt.sca(axes[1][0])
    home_conversion[:10].plot(kind='bar',color='yellow',alpha = 0.5)
    plt.ylabel('Conversion Percentage')
    plt.title('Home Conversion (2005/06 to 2020/21)')
    
    plt.sca(axes[1][1])
    away_conversion[:10].plot(kind='bar',color='green',alpha = 0.5)
    plt.ylabel('Conversion Percentage')
    plt.title('Away Conversion (2005/06 to 2020/21)') 
    
    fig.tight_layout(pad=1)
    
    return fig,axes

# %%
shots(Bundesliga)
# Out:
# (<Figure size 1080x1080 with 4 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x129341280>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x129519100>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x12967a520>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1295a6940>]],
#        dtype=object))

# %%
shots(EPL)
# Out:
# (<Figure size 1080x1080 with 4 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x129761f40>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1297a08b0>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x129854cd0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x12992c130>]],
#        dtype=object))

# %%
shots(LaLiga)
# Out:
# (<Figure size 1080x1080 with 4 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x129986760>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x1299ab9a0>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x129f49100>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x129fa7880>]],
#        dtype=object))

# %%
shots(SerieA)
# Out:
# (<Figure size 1080x1080 with 4 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12a0ad910>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x12a029a00>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x12ab2c8b0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x12ab6e070>]],
#        dtype=object))

# %%
def goals(league):
    goals=league.copy()
    home_goals=goals.groupby(['HomeTeam'])['FTHG'].sum()
    home_goals.sort_values(axis=0, ascending=False, inplace=True)
    away_goals=goals.groupby(['AwayTeam'])['FTAG'].sum()
    away_goals.sort_values(axis=0, ascending=False, inplace=True)
    total_goals=home_goals+away_goals
    total_goals.sort_values(axis=0, ascending=False, inplace=True)
    home_mean=goals.groupby(['HomeTeam'])['FTHG'].mean()
    home_mean.sort_values(axis=0, ascending=False, inplace=True)
    away_mean=goals.groupby(['AwayTeam'])['FTAG'].mean()
    away_mean.sort_values(axis=0, ascending=False, inplace=True)
    total_mean=(home_mean+away_mean)/2
    total_mean.sort_values(axis=0, ascending=False, inplace=True)
    
    fig,axes = plt.subplots(figsize = (15,15),nrows = 2, ncols = 3)
    plt.sca(axes[0][0])
    home_goals[:10].plot(kind = 'bar',color='red',alpha = 0.5)
    plt.ylabel('Goals')
    plt.title('Home Goals (2005/06 to 2020/21)')

    plt.sca(axes[0][1])
    away_goals[:10].plot(kind = 'bar',alpha = 0.5,color='yellow')
    plt.ylabel('Goals')
    plt.title('Away Goals (2005/06 to 2020/21)')
    
    plt.sca(axes[0][2])
    total_goals.plot(kind = 'line',color='blue',lw=2)
    plt.ylabel('Goals')
    plt.title('All-teams Goals (2005/06 to 2020/21)')
    
    plt.sca(axes[1][0])
    home_mean[:10].plot(kind = 'bar',color='orange',alpha = 0.5)
    plt.ylabel('Goal Average')
    plt.title('Goal Average per Game (2005/06 to 2020/21)')

    plt.sca(axes[1][1])
    away_mean[:10].plot(kind = 'bar',alpha = 0.5,color='brown')
    plt.ylabel('Goal Average')
    plt.title('Goal Average per Game (2005/06 to 2020/21)')
    
    plt.sca(axes[1][2])
    total_mean.plot(kind = 'line',color='blue',lw=2)
    plt.ylabel('Goals')
    plt.title('All-teams Average per Game (2005/06 to 2020/21)')
    
    fig.tight_layout(pad=1)
    return fig,axes

# %%
goals(Bundesliga)
# Out:
# (<Figure size 1080x1080 with 6 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12ac8ccd0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x12b67b160>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x12b6ad730>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x12b6d6040>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x12b707550>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x12b72dd60>]],
#        dtype=object))

# %%
Bundesliga
hom_goles=Bundesliga.groupby(['HomeTeam'])['FTHG'].mean()
visit_goles=Bundesliga.groupby(['AwayTeam'])['FTAG'].mean()

# %%
hom_goles
# Out:
# HomeTeam
# Aachen                1.647059
# Augsburg              1.441558
# Bayern Munich         2.792969
# Bielefeld             1.231884
# Bochum                1.411765
# Braunschweig          1.058824
# Cottbus               1.274510
# Darmstadt             0.970588
# Dortmund              2.152344
# Duisburg              1.058824
# Ein Frankfurt         1.523013
# FC Koln               1.280702
# Fortuna Dusseldorf    1.352941
# Freiburg              1.339181
# Greuther Furth        0.588235
# Hamburg               1.330317
# Hannover              1.552036
# Hansa Rostock         1.000000
# Hertha                1.351351
# Hoffenheim            1.721951
# Ingolstadt            1.264706
# Kaiserslautern        1.235294
# Karlsruhe             1.205882
# Leverkusen            1.878906
# M'gladbach            1.715481
# Mainz                 1.459459
# Nurnberg              1.320261
# Paderborn             1.235294
# RB Leipzig            2.086957
# Schalke 04            1.703125
# St Pauli              1.235294
# Stuttgart             1.567568
# Union Berlin          1.388889
# Werder Bremen         1.796875
# Wolfsburg             1.691406
# Name: FTHG, dtype: float64

# %%
TOT=hom_goles+visit_goles
TOT
# Out:
# HomeTeam
# Aachen                  46
# Augsburg               380
# Bayern Munich         1221
# Bielefeld              145
# Bochum                 169
# Braunschweig            29
# Cottbus                103
# Darmstadt               66
# Dortmund               991
# Duisburg                70
# Ein Frankfurt          631
# FC Koln                414
# Fortuna Dusseldorf     124
# Freiburg               417
# Greuther Furth          26
# Hamburg                549
# Hannover               572
# Hansa Rostock           30
# Hertha                 567
# Hoffenheim             660
# Ingolstadt              69
# Kaiserslautern         119
# Karlsruhe               68
# Leverkusen             900
# M'gladbach             682
# Mainz                  574
# Nurnberg               346
# Paderborn               68
# RB Leipzig             271
# Schalke 04             755
# St Pauli                35
# Stuttgart              644
# Union Berlin            43
# Werder Bremen          855
# Wolfsburg              772
# dtype: int64

# %% [markdown]
# # Poisson Distribution

# %% [markdown]
# The analysis of this distribution will consist on applying the model to a fixed season, taking into account the previous four, in order to check the effectiveness of the distribution

# %%
Bundesliga['season'].unique()
# Out:
# array(['200506', '200607', '200708', '200809', '200910', '201011',
#        '201112', '201213', '201314', '201415', '201516', '201617',
#        '201718', '201819', '201920', '202021'], dtype=object)

# %%
def turn_season_int(df):
    df['season']=df['season'].astype(str).astype(int)

# %%
turn_season_int(Bundesliga)

# %%
#defining a function to arrange each dataframe per season, starting in the 2007-08 season (the first one to posses
# four previous record seasons)

def df_array(season_number,league):
    s_df=league.loc[(league.season >= season_number-303) & (league.season <= season_number)] 
    #303 represents going further 3 seasons
    return s_df

# %%
# %%time
#let´s check the effectiveness choosing 4 seasons to test, the ones that group 3 previous seasons:
#2021: 1920,1819,1718
#1617: 1516,1415,1314
#1213: 1112,1011,0910
#0809: 0708,0607,0506

season_08_09=df_array(200809,Bundesliga)

season_12_13=df_array(201213,Bundesliga)

season_16_17=df_array(201617,Bundesliga)

season_20_21=df_array(202021,Bundesliga)
# Out:
# CPU times: user 9.99 ms, sys: 2.69 ms, total: 12.7 ms
# Wall time: 10.6 ms

# %%
##Adding the expected goals based on poisson distribution with the data from the previous 5 tournaments
def teams_strength_and_predictor(df,home,away):
    HomeTeam = df[['HomeTeam', 'FTHG', 'FTAG']].rename(
        columns={'HomeTeam':'Team', 'FTHG':'HomeScored', 'FTAG':'HomeConceded'}).groupby(
        ['Team'], as_index=False)[['HomeScored', 'HomeConceded']].mean()

    AwayTeam = df[['AwayTeam', 'FTHG', 'FTAG']].rename(
        columns={'AwayTeam':'Team', 'FTHG':'AwayConceded', 'FTAG':'AwayScored'}).groupby(
        ['Team'], as_index=False)[['AwayScored', 'AwayConceded']].mean()

    # Overall - Average {leagueHomeScored, leagueHomeConceded, leagueAwayScored, leagueAwayConceded}
    leagueHomeScored, leagueHomeConceded = HomeTeam['HomeScored'].mean(), HomeTeam['HomeConceded'].mean()
    leagueAwayScored, leagueAwayConceded = AwayTeam['AwayScored'].mean(), AwayTeam['AwayConceded'].mean()

    TeamStrength = pd.merge(HomeTeam, AwayTeam, on='Team')

    assert(leagueHomeScored != 0)
    assert(leagueHomeConceded != 0)
    assert(leagueAwayScored != 0)
    assert(leagueAwayConceded != 0)

    # Normalize the parameters 
    # For each team - {HomeAttack, HomeDefence, AwayAttack, AwayDefense}
    TeamStrength['HomeScored'] /= leagueHomeScored
    TeamStrength['HomeConceded'] /= leagueHomeConceded
    TeamStrength['AwayScored'] /= leagueAwayScored
    TeamStrength['AwayConceded'] /= leagueAwayConceded

    TeamStrength.columns=['Team','HomeAttack','HomeDefense','AwayAttack','AwayDefense']
    TeamStrength.set_index('Team', inplace=True)
    overallHomeScored = (leagueHomeScored+leagueAwayConceded)/2
    overallAwayScored = (leagueHomeConceded+leagueAwayScored)/2
    
    #after getting teams strength, we preceed to find the probabilities and expected scores
    
    if home in TeamStrength.index and away in TeamStrength.index:
        H = TeamStrength.at[home,'HomeAttack'] * TeamStrength.at[away,'AwayDefense'] * overallHomeScored
        A = TeamStrength.at[away,'AwayAttack'] * TeamStrength.at[home,'HomeDefense'] * overallAwayScored
        probH, probA, probT = 0, 0, 0  # Probability of Home win(H), Away win(A) or Tie(T) 
        for X in range(0,10):
            for Y in range(0, 10):
                p = poisson.pmf(X,H) * poisson.pmf(Y,A)
                if X == Y:
                    probT += p
                elif X > Y:
                    probH += p
                else:
                    probA += p
        HomeProb=round(probH*100,2)
        TieProb=round(probT*100,2)
        AwayProb=round(probA*100,2)
        scoreH = 3 * probH + probT
        scoreA = 3 * probA + probT
        return (scoreH,scoreA,HomeProb,TieProb,AwayProb)
    else:
        return (0,0,0,0,0)

# %%
def predictor(season):
    dummy=season.copy()
    Home_goals=[]
    Away_goals=[]
    home_chance=[]
    tie_chance=[]
    away_chance=[]
    for index, row in dummy.iterrows():
        home, away = row['HomeTeam'], row['AwayTeam']
        rH,rA,cH,cT,cA = teams_strength_and_predictor(season,home,away)
        Home_goals.append(round(rH,2))
        Away_goals.append(round(rA,2))
        home_chance.append(round(cH,2))
        tie_chance.append(round(cT,2))
        away_chance.append(round(cA,2))
    
    dummy['HomeExpectedGoals']=Home_goals
    dummy['AwayExpectedGoals']=Away_goals
    dummy['HomeProbability']=home_chance
    dummy['TieProbability']=tie_chance
    dummy['AwayProbability']=away_chance
    
    return dummy

# %%
# %%time
#Here the function gets the Poisson prediction for every season since 08_09

s0809=predictor(season_08_09)

s1213=predictor(season_12_13)

s1617=predictor(season_16_17)

s2021=predictor(season_20_21)
# Out:
# CPU times: user 3min 55s, sys: 997 ms, total: 3min 56s
# Wall time: 3min 56s

# %%
seasons_poisson=pd.concat([s0809,s1213,s1617,s2021])
seasons_poisson.drop(['HS','AS','B365H','B365D','B365A'], axis=1, inplace=True)
seasons_poisson
# Out:
#           Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  season  \
# 0   05/08/2005  Bayern Munich     M'gladbach     3     0   H  200506
# 1   06/08/2005       Duisburg      Stuttgart     1     1   D  200506
# 2   06/08/2005        FC Koln          Mainz     1     0   H  200506
# 3   06/08/2005        Hamburg       Nurnberg     3     0   H  200506
# 4   06/08/2005       Hannover         Hertha     2     2   D  200506
# ..         ...            ...            ...   ...   ...  ..     ...
# 13  26/09/2020          Mainz      Stuttgart     1     4   A  202021
# 14  26/09/2020     M'gladbach   Union Berlin     1     1   D  202021
# 15  26/09/2020     Schalke 04  Werder Bremen     1     3   A  202021
# 16  27/09/2020     Hoffenheim  Bayern Munich     4     1   H  202021
# 17  27/09/2020       Freiburg      Wolfsburg     1     1   D  202021
#
#     HomeExpectedGoals  AwayExpectedGoals  HomeProbability  TieProbability  \
# 0                2.59               0.28            82.38           12.32
# 1                0.92               1.84            22.91           23.40
# 2                1.34               1.37            34.91           29.29
# 3                1.98               0.76            57.20           26.09
# 4                1.54               1.22            43.51           23.85
# ..                ...                ...              ...             ...
# 13               1.84               0.92            53.41           24.02
# 14               2.32               0.52            71.78           16.31
# 15               1.17               1.57            30.11           26.16
# 16               0.61               2.22            14.58           16.92
# 17               1.37               1.36            36.36           27.58
#
#     AwayProbability
# 0              5.26
# 1             53.69
# 2             35.79
# 3             16.72
# 4             32.64
# ..              ...
# 13            22.56
# 14            11.88
# 15            43.73
# 16            68.48
# 17            36.06
#
# [4608 rows x 12 columns]

# %%
bundesliga_poisson['season'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-c9d70e6baea5> in <module>
# ----> 1 bundesliga_poisson['season'].value_counts()
#
# NameError: name 'bundesliga_poisson' is not defined

# %%
selected_seasons=[200809,201213,201617,202021]
bundesliga_poisson = seasons_poisson[seasons_poisson['season'].isin(selected_seasons)] 
bundesliga_poisson
# Out:
#           Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  season  \
# 0   15/08/2008  Bayern Munich        Hamburg     2     2   D  200809
# 1   16/08/2008      Bielefeld  Werder Bremen     2     2   D  200809
# 2   16/08/2008        Cottbus     Hoffenheim     0     3   A  200809
# 3   16/08/2008      Karlsruhe         Bochum     1     0   H  200809
# 4   16/08/2008     Leverkusen       Dortmund     2     3   A  200809
# ..         ...            ...            ...   ...   ...  ..     ...
# 13  26/09/2020          Mainz      Stuttgart     1     4   A  202021
# 14  26/09/2020     M'gladbach   Union Berlin     1     1   D  202021
# 15  26/09/2020     Schalke 04  Werder Bremen     1     3   A  202021
# 16  27/09/2020     Hoffenheim  Bayern Munich     4     1   H  202021
# 17  27/09/2020       Freiburg      Wolfsburg     1     1   D  202021
#
#     HomeExpectedGoals  AwayExpectedGoals  HomeProbability  TieProbability  \
# 0                1.93               0.83            56.41           23.88
# 1                0.93               1.83            23.20           23.60
# 2                0.98               1.81            25.84           20.83
# 3                1.27               1.45            32.68           28.57
# 4                1.74               1.03            50.52           22.72
# ..                ...                ...              ...             ...
# 13               1.84               0.92            53.41           24.02
# 14               2.32               0.52            71.78           16.31
# 15               1.17               1.57            30.11           26.16
# 16               0.61               2.22            14.58           16.92
# 17               1.37               1.36            36.36           27.58
#
#     AwayProbability
# 0             19.70
# 1             53.20
# 2             53.32
# 3             38.76
# 4             26.76
# ..              ...
# 13            22.56
# 14            11.88
# 15            43.73
# 16            68.48
# 17            36.06
#
# [936 rows x 12 columns]

# %%
Home_P[65]-Away_P[135]
# Out:
# 13.64

# %%
def predicted(row):
    if (row['HomeProbability']-row['AwayProbability'])<=5.0 and (row['AwayProbability']-row['HomeProbability'])<=5.0:
        res='D'
    elif row['HomeProbability']>row['AwayProbability'] and row['HomeProbability']>row['TieProbability']:
        res='H'
    elif row['HomeProbability']<row['AwayProbability'] and row['AwayProbability']>row['TieProbability']:
        res='A'
    elif row['HomeProbability']<row['TieProbability'] and row['AwayProbability']<row['TieProbability']:
        res='D'
    
    return res

# %%
bundesliga_poisson['PoissonPredicted']=bundesliga_poisson.apply(predicted,axis=1)

# %%
bundesliga_poisson
# Out:
#           Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  season  \
# 0   15/08/2008  Bayern Munich        Hamburg     2     2   D  200809
# 1   16/08/2008      Bielefeld  Werder Bremen     2     2   D  200809
# 2   16/08/2008        Cottbus     Hoffenheim     0     3   A  200809
# 3   16/08/2008      Karlsruhe         Bochum     1     0   H  200809
# 4   16/08/2008     Leverkusen       Dortmund     2     3   A  200809
# ..         ...            ...            ...   ...   ...  ..     ...
# 13  26/09/2020          Mainz      Stuttgart     1     4   A  202021
# 14  26/09/2020     M'gladbach   Union Berlin     1     1   D  202021
# 15  26/09/2020     Schalke 04  Werder Bremen     1     3   A  202021
# 16  27/09/2020     Hoffenheim  Bayern Munich     4     1   H  202021
# 17  27/09/2020       Freiburg      Wolfsburg     1     1   D  202021
#
#     HomeExpectedGoals  AwayExpectedGoals  HomeProbability  TieProbability  \
# 0                1.93               0.83            56.41           23.88
# 1                0.93               1.83            23.20           23.60
# 2                0.98               1.81            25.84           20.83
# 3                1.27               1.45            32.68           28.57
# 4                1.74               1.03            50.52           22.72
# ..                ...                ...              ...             ...
# 13               1.84               0.92            53.41           24.02
# 14               2.32               0.52            71.78           16.31
# 15               1.17               1.57            30.11           26.16
# 16               0.61               2.22            14.58           16.92
# 17               1.37               1.36            36.36           27.58
#
#     AwayProbability PoissonPredicted  Rigth/Wrong
# 0             19.70                H            0
# 1             53.20                A            0
# 2             53.32                A            1
# 3             38.76                A            0
# 4             26.76                H            0
# ..              ...              ...          ...
# 13            22.56                H            0
# 14            11.88                H            0
# 15            43.73                A            1
# 16            68.48                A            0
# 17            36.06                D            1
#
# [936 rows x 14 columns]

# %%
bundesliga_poisson['PoissonPredicted'].value_counts()
# Out:
# H    601
# A    230
# D    105
# Name: PoissonPredicted, dtype: int64

# %%
bundesliga_poisson['Rigth/Wrong']=np.where(bundesliga_poisson['FTR']==bundesliga_poisson['PoissonPredicted'],1,0)

# %%
bundesliga_poisson
# Out:
#           Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  season  \
# 0   15/08/2008  Bayern Munich        Hamburg     2     2   D  200809
# 1   16/08/2008      Bielefeld  Werder Bremen     2     2   D  200809
# 2   16/08/2008        Cottbus     Hoffenheim     0     3   A  200809
# 3   16/08/2008      Karlsruhe         Bochum     1     0   H  200809
# 4   16/08/2008     Leverkusen       Dortmund     2     3   A  200809
# ..         ...            ...            ...   ...   ...  ..     ...
# 13  26/09/2020          Mainz      Stuttgart     1     4   A  202021
# 14  26/09/2020     M'gladbach   Union Berlin     1     1   D  202021
# 15  26/09/2020     Schalke 04  Werder Bremen     1     3   A  202021
# 16  27/09/2020     Hoffenheim  Bayern Munich     4     1   H  202021
# 17  27/09/2020       Freiburg      Wolfsburg     1     1   D  202021
#
#     HomeExpectedGoals  AwayExpectedGoals  HomeProbability  TieProbability  \
# 0                1.93               0.83            56.41           23.88
# 1                0.93               1.83            23.20           23.60
# 2                0.98               1.81            25.84           20.83
# 3                1.27               1.45            32.68           28.57
# 4                1.74               1.03            50.52           22.72
# ..                ...                ...              ...             ...
# 13               1.84               0.92            53.41           24.02
# 14               2.32               0.52            71.78           16.31
# 15               1.17               1.57            30.11           26.16
# 16               0.61               2.22            14.58           16.92
# 17               1.37               1.36            36.36           27.58
#
#     AwayProbability PoissonPredicted  Rigth/Wrong
# 0             19.70                H            0
# 1             53.20                A            0
# 2             53.32                A            1
# 3             38.76                A            0
# 4             26.76                H            0
# ..              ...              ...          ...
# 13            22.56                H            0
# 14            11.88                H            0
# 15            43.73                A            1
# 16            68.48                A            0
# 17            36.06                D            1
#
# [936 rows x 14 columns]

# %%
bundesliga_poisson['Rigth/Wrong'].value_counts()
# Out:
# 1    476
# 0    460
# Name: Rigth/Wrong, dtype: int64

# %%
47600/936
# Out:
# 50.85470085470085

# %% [markdown]
# # Bookers probabilities

# %% [markdown]
# With the Bet365 picks we can know who was the favorite team in each match(the minor odd), but the question here is, how accurate it´s the betting site prediction to pick the right team?

# %%
b365_bundesliga=Bundesliga.copy()

# %%
b365_bundesliga.drop(['HS','AS','season'],axis=1,inplace=True)

# %%
B365_H=b365_bundesliga['B365H'].to_list()
B365_D=b365_bundesliga['B365D'].to_list()
B365_A=b365_bundesliga['B365A'].to_list()

# %%
B365Result=[]
c=0
while c<len(B365_H):
    if B365_H[c]<B365_D[c] and B365_H[c]<B365_A[c]:
        B365Result.append('H')
    elif B365_D[c]<B365_H[c] and B365_D[c]<B365_A[c]:
        B365Result.append('D')
    elif B365_A[c]<B365_H[c] and B365_A[c]<B365_D[c]:
        B365Result.append('A')
    elif B365_H[c]==B365_D[c] or B365_H[c]==B365_A[c]:
        B365Result.append('H')
    elif B365_A[c]==B365_D[c] or B365_H[c]==B365_A[c]:
        B365Result.append('A')
    
        
        
    else:
        B365Result.append('N')
        
    c+=1

# %%
b365_bundesliga['B365Result']=B365Result

# %%
b365_bundesliga
# Out:
#           Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  B365H  B365D  \
# 0   05/08/2005  Bayern Munich     M'gladbach     3     0   H   1.30   5.00
# 1   06/08/2005       Duisburg      Stuttgart     1     1   D   2.75   3.25
# 2   06/08/2005        FC Koln          Mainz     1     0   H   2.10   3.25
# 3   06/08/2005        Hamburg       Nurnberg     3     0   H   1.57   3.40
# 4   06/08/2005       Hannover         Hertha     2     2   D   2.40   3.20
# ..         ...            ...            ...   ...   ...  ..    ...    ...
# 13  26/09/2020          Mainz      Stuttgart     1     4   A   2.37   3.50
# 14  26/09/2020     M'gladbach   Union Berlin     1     1   D   1.44   4.50
# 15  26/09/2020     Schalke 04  Werder Bremen     1     3   A   2.50   3.40
# 16  27/09/2020     Hoffenheim  Bayern Munich     4     1   H  11.00   7.50
# 17  27/09/2020       Freiburg      Wolfsburg     1     1   D   3.20   3.30
#
#     B365A B365Result
# 0    9.50          H
# 1    2.25          A
# 2    3.00          H
# 3    5.50          H
# 4    2.60          H
# ..    ...        ...
# 13   2.90          H
# 14   7.50          H
# 15   2.80          H
# 16   1.20          A
# 17   2.30          A
#
# [4608 rows x 10 columns]

# %%
comparision=b365_bundesliga['FTR']==b365_bundesliga['B365Result']

# %%
comparision.value_counts()
# Out:
# True     2357
# False    2251
# dtype: int64

# %%
b365_bundesliga['Serie']=comparision

# %%
b365_right=b365_bundesliga[b365_bundesliga['FTR']==b365_bundesliga['B365Result']]

# %%
b365_fail=b365_bundesliga[b365_bundesliga['FTR']!=b365_bundesliga['B365Result']]

# %%
b365_bundesliga['B365Result'].value_counts()
# Out:
# H    3350
# A    1258
# Name: B365Result, dtype: int64

# %%
b365_right
# Out:
#            Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  B365H  B365D  \
# 0    05/08/2005  Bayern Munich     M'gladbach     3     0   H   1.30   5.00
# 2    06/08/2005        FC Koln          Mainz     1     0   H   2.10   3.25
# 3    06/08/2005        Hamburg       Nurnberg     3     0   H   1.57   3.40
# 5    06/08/2005  Werder Bremen      Bielefeld     5     2   H   1.44   3.75
# 7    07/08/2005  Ein Frankfurt     Leverkusen     1     4   A   2.75   3.25
# ..          ...            ...            ...   ...   ...  ..    ...    ...
# 304  27/06/2020  Werder Bremen        FC Koln     6     1   H   1.57   4.20
# 305  27/06/2020      Wolfsburg  Bayern Munich     0     4   A   4.33   4.33
# 0    18/09/2020  Bayern Munich     Schalke 04     8     0   H   1.10  11.00
# 6    19/09/2020       Dortmund     M'gladbach     3     0   H   1.60   4.33
# 7    20/09/2020     RB Leipzig          Mainz     3     1   H   1.33   5.75
#
#      B365A B365Result  Serie
# 0     9.50          H   True
# 2     3.00          H   True
# 3     5.50          H   True
# 5     6.50          H   True
# 7     2.25          A   True
# ..     ...        ...    ...
# 304   5.25          H   True
# 305   1.70          A   True
# 0    21.00          H   True
# 6     5.00          H   True
# 7     8.00          H   True
#
# [2357 rows x 11 columns]

# %%
b365_right['fav']=np.where(b365_right['FTR']=='H',b365_right['HomeTeam'],b365_right['AwayTeam'])

# %%
b365_right
# Out:
#            Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  B365H  B365D  \
# 0    05/08/2005  Bayern Munich     M'gladbach     3     0   H   1.30   5.00
# 2    06/08/2005        FC Koln          Mainz     1     0   H   2.10   3.25
# 3    06/08/2005        Hamburg       Nurnberg     3     0   H   1.57   3.40
# 5    06/08/2005  Werder Bremen      Bielefeld     5     2   H   1.44   3.75
# 7    07/08/2005  Ein Frankfurt     Leverkusen     1     4   A   2.75   3.25
# ..          ...            ...            ...   ...   ...  ..    ...    ...
# 304  27/06/2020  Werder Bremen        FC Koln     6     1   H   1.57   4.20
# 305  27/06/2020      Wolfsburg  Bayern Munich     0     4   A   4.33   4.33
# 0    18/09/2020  Bayern Munich     Schalke 04     8     0   H   1.10  11.00
# 6    19/09/2020       Dortmund     M'gladbach     3     0   H   1.60   4.33
# 7    20/09/2020     RB Leipzig          Mainz     3     1   H   1.33   5.75
#
#      B365A B365Result  Serie            fav
# 0     9.50          H   True  Bayern Munich
# 2     3.00          H   True        FC Koln
# 3     5.50          H   True        Hamburg
# 5     6.50          H   True  Werder Bremen
# 7     2.25          A   True     Leverkusen
# ..     ...        ...    ...            ...
# 304   5.25          H   True  Werder Bremen
# 305   1.70          A   True  Bayern Munich
# 0    21.00          H   True  Bayern Munich
# 6     5.00          H   True       Dortmund
# 7     8.00          H   True     RB Leipzig
#
# [2357 rows x 12 columns]

# %%
b365_fail
# Out:
#           Date    HomeTeam       AwayTeam  FTHG  FTAG FTR  B365H  B365D  \
# 1   06/08/2005    Duisburg      Stuttgart     1     1   D   2.75   3.25
# 4   06/08/2005    Hannover         Hertha     2     2   D   2.40   3.20
# 6   06/08/2005   Wolfsburg       Dortmund     2     2   D   2.37   3.20
# 10  13/08/2005    Dortmund     Schalke 04     1     2   A   2.50   3.00
# 14  13/08/2005  M'gladbach      Wolfsburg     1     1   D   2.10   3.25
# ..         ...         ...            ...   ...   ...  ..    ...    ...
# 13  26/09/2020       Mainz      Stuttgart     1     4   A   2.37   3.50
# 14  26/09/2020  M'gladbach   Union Berlin     1     1   D   1.44   4.50
# 15  26/09/2020  Schalke 04  Werder Bremen     1     3   A   2.50   3.40
# 16  27/09/2020  Hoffenheim  Bayern Munich     4     1   H  11.00   7.50
# 17  27/09/2020    Freiburg      Wolfsburg     1     1   D   3.20   3.30
#
#     B365A B365Result  Serie
# 1    2.25          A  False
# 4    2.60          H  False
# 6    2.62          H  False
# 10   2.62          H  False
# 14   3.00          H  False
# ..    ...        ...    ...
# 13   2.90          H  False
# 14   7.50          H  False
# 15   2.80          H  False
# 16   1.20          A  False
# 17   2.30          A  False
#
# [2251 rows x 11 columns]

# %%
b365_fail['fav']=np.where(b365_fail['FTR']=='H',b365_fail['HomeTeam'],b365_fail['AwayTeam'])

# %%
b365_fail
# Out:
#           Date    HomeTeam       AwayTeam  FTHG  FTAG FTR  B365H  B365D  \
# 1   06/08/2005    Duisburg      Stuttgart     1     1   D   2.75   3.25
# 4   06/08/2005    Hannover         Hertha     2     2   D   2.40   3.20
# 6   06/08/2005   Wolfsburg       Dortmund     2     2   D   2.37   3.20
# 10  13/08/2005    Dortmund     Schalke 04     1     2   A   2.50   3.00
# 14  13/08/2005  M'gladbach      Wolfsburg     1     1   D   2.10   3.25
# ..         ...         ...            ...   ...   ...  ..    ...    ...
# 13  26/09/2020       Mainz      Stuttgart     1     4   A   2.37   3.50
# 14  26/09/2020  M'gladbach   Union Berlin     1     1   D   1.44   4.50
# 15  26/09/2020  Schalke 04  Werder Bremen     1     3   A   2.50   3.40
# 16  27/09/2020  Hoffenheim  Bayern Munich     4     1   H  11.00   7.50
# 17  27/09/2020    Freiburg      Wolfsburg     1     1   D   3.20   3.30
#
#     B365A B365Result  Serie            fav
# 1    2.25          A  False      Stuttgart
# 4    2.60          H  False         Hertha
# 6    2.62          H  False       Dortmund
# 10   2.62          H  False     Schalke 04
# 14   3.00          H  False      Wolfsburg
# ..    ...        ...    ...            ...
# 13   2.90          H  False      Stuttgart
# 14   7.50          H  False   Union Berlin
# 15   2.80          H  False  Werder Bremen
# 16   1.20          A  False     Hoffenheim
# 17   2.30          A  False      Wolfsburg
#
# [2251 rows x 12 columns]

# %%
b365_right['fav'].value_counts()
# Out:
# Bayern Munich         358
# Dortmund              243
# Leverkusen            198
# Schalke 04            190
# Werder Bremen         139
# Wolfsburg             133
# M'gladbach            126
# Stuttgart             126
# Hoffenheim             97
# Hamburg                95
# Hertha                 89
# Ein Frankfurt          82
# Mainz                  80
# RB Leipzig             64
# Hannover               64
# Augsburg               47
# FC Koln                43
# Freiburg               43
# Nurnberg               43
# Bielefeld              16
# Bochum                 13
# Cottbus                12
# Kaiserslautern         11
# Ingolstadt              9
# Fortuna Dusseldorf      6
# Karlsruhe               5
# Aachen                  4
# Union Berlin            4
# Duisburg                4
# St Pauli                4
# Hansa Rostock           3
# Paderborn               3
# Darmstadt               2
# Braunschweig            1
# Name: fav, dtype: int64

# %%
b365_fail['fav'].value_counts()
# Out:
# Ein Frankfurt         134
# Werder Bremen         127
# Mainz                 126
# Wolfsburg             125
# Hannover              124
# Hertha                120
# Hamburg               116
# M'gladbach            113
# Freiburg              113
# Hoffenheim            110
# Schalke 04            107
# Leverkusen             99
# Stuttgart              97
# Dortmund               93
# FC Koln                90
# Augsburg               86
# Nurnberg               80
# Bayern Munich          53
# Bielefeld              43
# Bochum                 41
# Fortuna Dusseldorf     34
# Cottbus                31
# RB Leipzig             26
# Kaiserslautern         25
# Darmstadt              20
# Karlsruhe              19
# Paderborn              18
# Ingolstadt             17
# Duisburg               14
# Union Berlin           11
# Greuther Furth          9
# Braunschweig            9
# Aachen                  8
# Hansa Rostock           7
# St Pauli                6
# Name: fav, dtype: int64

# %%
pivot=pd.crosstab(b365_right['fav'],b365_fail['fav'],margins = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-c86c336391d9> in <module>
# ----> 1 pivot=pd.crosstab(b365_right['fav'],b365_fail['fav'],margins = True)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     581     from pandas import DataFrame
#     582
# --> 583     df = DataFrame(data, index=common_idx)
#     584     if values is None:
#     585         df["__dummy__"] = 0
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      67
#      68     # don't force copy because getting jammed in an ndarray anyway
# ---> 69     arrays = _homogenize(arrays, index, dtype)
#      70
#      71     # from BlockManager perspective
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     309                 # Forces alignment. No need to copy data since we
#     310                 # are putting it into an ndarray later
# --> 311                 val = val.reindex(index, copy=False)
#     312         else:
#     313             if isinstance(val, dict):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    4028     @Appender(generic.NDFrame.reindex.__doc__)
#    4029     def reindex(self, index=None, **kwargs):
# -> 4030         return super().reindex(index=index, **kwargs)
#    4031
#    4032     def drop(
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4541
#    4542         # perform the reindex on the axes
# -> 4543         return self._reindex_axes(
#    4544             axes, level, limit, tolerance, method, fill_value, copy
#    4545         ).__finalize__(self)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4561
#    4562             axis = self._get_axis_number(a)
# -> 4563             obj = obj._reindex_with_indexers(
#    4564                 {axis: [new_index, indexer]},
#    4565                 fill_value=fill_value,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4605
#    4606             # TODO: speed up on homogeneous DataFrame objects
# -> 4607             new_data = new_data.reindex_indexer(
#    4608                 index,
#    4609                 indexer,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1249         # some axes don't allow reindexing with dups
#    1250         if not allow_dups:
# -> 1251             self.axes[axis]._can_reindex(indexer)
#    1252
#    1253         if axis >= self.ndim:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in _can_reindex(self, indexer)
#    3097         # trying to reindex on an axis with duplicates
#    3098         if not self.is_unique and len(indexer):
# -> 3099             raise ValueError("cannot reindex from a duplicate axis")
#    3100
#    3101     def reindex(self, target, method=None, level=None, limit=None, tolerance=None):
#
# ValueError: cannot reindex from a duplicate axis
